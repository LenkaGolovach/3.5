# %% [markdown]
# ### Самостоятельное задание
# Создать ноутбук, в котором выполнить решение вычислительной задачи (например, задачи из области физики, экономики, математики, статистики и т. д.) требующей построения круговой диаграммы, условие которой предварительно необходимо согласовать с преподавателем.

# %% [markdown]
# В ресторане проводится анализ по предпочтениям клиентов в отношении типов пиццы. Имеются данные о количестве заказов трех типов пиццы: маргарита, пепперони и гавайская. Необходимо сравнить популярность каждого типа пиццы и определить, какой тип пиццы является наиболее востребованным.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Задаём параметры

# %%
pizza_types = ['Маргарита', 'Пепперони', 'Гавайская']
orders = [120, 90, 150]
explode = (0.1, 0.1, 0.15)

# %% [markdown]
# Выводим диаграмму

# %%
fig, ax = plt.subplots()

ax.pie(orders, labels=pizza_types, autopct='%1.1f%%', shadow=True, explode=explode,
       wedgeprops={'lw': 1, 'ls': '--', 'edgecolor': "k"})
ax.set_facecolor('xkcd:salmon')
ax.set_facecolor(('#0F0F0F'))
ax.axis("equal")
ax.set_title('Предпочтения клиентов по типам пиццы')

plt.show()
